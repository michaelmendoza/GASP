# %%
import sys
sys.path.insert(0, '../../')

import numpy as np
import matplotlib.pyplot as plt 
from gasp import ssfp, phantom, tissue

# %%
img = phantom.phantom_generator(type='shepp_logan')
plt.imshow(np.abs(img[:,:,0]))

# %%
img = phantom.phantom_generator(type='circles')
plt.imshow(np.abs(img[:,:,0]))

# %%
img = phantom.phantom_generator(type='block')
plt.imshow(np.abs(img[:,:,0]))

# %%
img = phantom.phantom_generator(type='blocks')
plt.imshow(np.abs(img[:,:,0]))

# %%
t = tissue.tissue_generator(type='blocks')
plt.imshow(t['mask'])
plt.show()
plt.imshow(t['t1'])
plt.show()
plt.imshow(t['t2'])
plt.show()
