# %%
import sys, os
sys.path.insert(0, '../../')
from pathlib import Path
import math
import numpy as np
import matplotlib.pyplot as plt 
from gasp import load_dataset

import logging
logging.getLogger('gasp.dataset').setLevel(logging.DEBUG)
logging.basicConfig()

# %%
ds = {
    'name':'2025_08_19_phantom_mendoza',
    'path':'2025_08_19_phantom_mendoza',
    'subfolder':'twix'
}

M = load_dataset(**ds, filter='_fa60_')
print('shape: ', M.shape)
# Out:
# DEBUG:gasp.dataset:Filter: _fa60_
# DEBUG:gasp.dataset:Loading from: /Users/michael/projects/mri/GASP/notebooks/datasets/../../gasp/../data/2025_08_19_phantom_mendoza/twix
# DEBUG:gasp.dataset:Files: ['meas_MID97_bSSFP_gasp_knee_fa60_TR7ms_FID83691.dat', 'meas_MID98_bSSFP_gasp_knee_fa60_TR14ms_FID83692.dat', 'meas_MID99_bSSFP_gasp_knee_fa60_TR28ms_FID83693.dat']
# Data: 2025_08_19_phantom_mendoza data exists
# pymapVBVD version 0.6.1
# Software version: VB
# pymapVBVD version 0.6.1
# Software version: VB
# pymapVBVD version 0.6.1
# Software version: VB
# shape:  (256, 256, 8, 16, 3)
