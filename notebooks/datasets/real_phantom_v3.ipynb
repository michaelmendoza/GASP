# %%
import sys
sys.path.insert(0, '../../')

from gasp import dataloader, view

# %%
filepath = '/Users/michael/projects/MRI/data/2019_GASP/20190507_GASP_LONG_TR_WATER/'
files = ['meas_MID12_TRUFI_TE12_FID42712.dat',
         'meas_MID13_TRUFI_TE24_FID42713.dat',
         'meas_MID14_TRUFI_TE48_FID42714.dat']

# %%
data = dataloader.read_rawdata(filepath + files[0])
M = data['data']
view.view3D('bssfp_v3_phantom0.gif', M)
# Out:
# pymapVBVD version 0.4.8
# Software version: VB
# Scan 1/1, read all mdhs:   0%|          | 0.00/528M [00:00<?, ?B/s]
# read data:   0%|          | 0/32767 [00:00<?, ?it/s]
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ./images/bssfp_v3_phantom0.gif

# %%
data = dataloader.read_rawdata(filepath + files[1])
M = data['data']
view.view3D('bssfp_v3_phantom1.gif', M)
# Out:
# pymapVBVD version 0.4.8
# Software version: VB
# Scan 1/1, read all mdhs:   0%|          | 0.00/528M [00:00<?, ?B/s]
# read data:   0%|          | 0/32767 [00:00<?, ?it/s]
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ./images/bssfp_v3_phantom1.gif

# %%
data = dataloader.read_rawdata(filepath + files[2])
M = data['data']
view.view3D('bssfp_v3_phantom2.gif', M)
# Out:
# pymapVBVD version 0.4.8
# Software version: VB
# Scan 1/1, read all mdhs:   0%|          | 0.00/528M [00:00<?, ?B/s]
# read data:   0%|          | 0/32767 [00:00<?, ?it/s]
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ./images/bssfp_v3_phantom2.gif
