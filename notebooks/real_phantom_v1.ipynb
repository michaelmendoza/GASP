# %%
import sys
sys.path.insert(0, '../')

from gasp import dataloader, view

# %%
filepath = '/Users/michael/projects/MRI/data/2019_GASP/20190401_GASP_PHANTOM/'
files = ['meas_MID48_TRUFI_NBPM_2019_02_27_FID41503.dat',
         'meas_MID49_TRUFI_NBPM_2019_02_27_FID41504.dat',
         'meas_MID50_TRUFI_NBPM_2019_02_27_FID41505.dat']

# %%
data = dataloader.read_rawdata(filepath + files[0])
M = data['data']
view.view3D('bssfp_v1_phantom0.gif', M)
# Out:
# pymapVBVD version 0.4.8
# Software version: VB
# Scan 1/1, read all mdhs:   0%|          | 0.00/136M [00:00<?, ?B/s]
# read data:   0%|          | 0/16383 [00:00<?, ?it/s]
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ./images/bssfp_v1_phantom0.gif

# %%
data = dataloader.read_rawdata(filepath + files[1])
M = data['data']
view.view3D('bssfp_v1_phantom1.gif', M)
# Out:
# pymapVBVD version 0.4.8
# Software version: VB
# Scan 1/1, read all mdhs:   0%|          | 0.00/136M [00:00<?, ?B/s]
# read data:   0%|          | 0/16383 [00:00<?, ?it/s]
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ./images/bssfp_v1_phantom1.gif

# %%
data = dataloader.read_rawdata(filepath + files[2])
M = data['data']
view.view3D('bssfp_v1_phantom2.gif', M)
# Out:
# pymapVBVD version 0.4.8
# Software version: VB
# Scan 1/1, read all mdhs:   0%|          | 0.00/136M [00:00<?, ?B/s]
# read data:   0%|          | 0/16383 [00:00<?, ?it/s]
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ./images/bssfp_v1_phantom2.gif
